# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import ipywidgets as widgets

# %%
disciplinas = pd.read_csv('componentes-curriculares-presenciais.csv', 
                          sep=';', 
                          usecols=["id_componente","codigo","nivel","nome","unidade_responsavel"])
docentes = pd.read_csv('docentes.csv', sep=';')

# %%
# Limpando o dataframe disciplinas com linhas desnecessárias
disciplinas.dropna(inplace=True)
disciplinas = disciplinas[~disciplinas.id_componente.duplicated()]

# %%
turmas_imd_nomesprof.head()
# Out:
#    id_turma   codigo nivel_ensino                           nome_y  \
# 0  57586177  IMD0029    GRADUAÇÃO       SELAN RODRIGUES DOS SANTOS
# 1  57586198  IMD0030    GRADUAÇÃO       SELAN RODRIGUES DOS SANTOS
# 2  57586359  IMD0029    GRADUAÇÃO                CESAR RENNO COSTA
# 3  57586373  IMD0030    GRADUAÇÃO                CESAR RENNO COSTA
# 4  57586359  IMD0029    GRADUAÇÃO  JORGE ESTEFANO SANTANA DE SOUZA
#
#                          nome_x  capacidade_aluno  \
# 0  ESTRUTURA DE DADOS BÁSICAS I                60
# 1    LINGUAGEM DE PROGRAMAÇÃO I                30
# 2  ESTRUTURA DE DADOS BÁSICAS I                60
# 3    LINGUAGEM DE PROGRAMAÇÃO I                32
# 4  ESTRUTURA DE DADOS BÁSICAS I                60
#
#                  descricao_horario
# 0  35M12 (25/07/2016 - 17/12/2016)
# 1  35M34 (25/07/2016 - 17/12/2016)
# 2  35N12 (25/07/2016 - 17/12/2016)
# 3  35N34 (25/07/2016 - 17/12/2016)
# 4  35N12 (25/07/2016 - 17/12/2016)

# %%
turmas = pd.read_csv('Dados Turma/turmas-2016.2.csv', sep=';')
turmas2 = pd.read_csv('Dados Turma/turmas-2016.1.csv', sep=';')
turmas3 = pd.read_csv('Dados Turma/turmas-2015.2.csv', sep=';')
turmas4 = pd.read_csv('Dados Turma/turmas-2015.1.csv', sep=';')
turmas5 = pd.read_csv('Dados Turma/turmas-2014.2.csv', sep=';')
turmas6 = pd.read_csv('Dados Turma/turmas-2014.1.csv', sep=';')

# %%
turmas.rename(columns={'id_componente_curricular': 'id_componente'}, inplace=True)
turmas.id_componente = turmas.id_componente.astype(str)

turmas2.rename(columns={'id_componente_curricular': 'id_componente'}, inplace=True)
turmas2.id_componente = turmas.id_componente.astype(str)

turmas3.rename(columns={'id_componente_curricular': 'id_componente'}, inplace=True)
turmas3.id_componente = turmas.id_componente.astype(str)

turmas4.rename(columns={'id_componente_curricular': 'id_componente'}, inplace=True)
turmas4.id_componente = turmas.id_componente.astype(str)

turmas5.rename(columns={'id_componente_curricular': 'id_componente'}, inplace=True)
turmas5.id_componente = turmas.id_componente.astype(str)

turmas6.rename(columns={'id_componente_curricular': 'id_componente'}, inplace=True)
turmas6.id_componente = turmas.id_componente.astype(str)

# %%
colunas = ["id_turma","id_docente_interno","codigo","nivel_ensino","nome","unidade_responsavel",
          "situacao_turma","capacidade_aluno","descricao_horario"]

merge_turmas_disciplinas = pd.merge(turmas, disciplinas, on='id_componente')[colunas]
merge_turmas_disciplinas.dropna(inplace=True)

# %%
merge_turmas_disciplinas2 = pd.merge(turmas2, disciplinas, on='id_componente')[colunas]
merge_turmas_disciplinas2.dropna(inplace=True)

# %%
merge_turmas_disciplinas3 = pd.merge(turmas3, disciplinas, on='id_componente')[colunas]
merge_turmas_disciplinas3.dropna(inplace=True)

# %%
merge_turmas_disciplinas4 = pd.merge(turmas4, disciplinas, on='id_componente')[colunas]
merge_turmas_disciplinas4.dropna(inplace=True)

# %%
merge_turmas_disciplinas5 = pd.merge(turmas5, disciplinas, on='id_componente')[colunas]
merge_turmas_disciplinas5.dropna(inplace=True)

# %%
merge_turmas_disciplinas6 = pd.merge(turmas6, disciplinas, on='id_componente')[colunas]
merge_turmas_disciplinas6.dropna(inplace=True)

# %%
# filtrando as turmas com código IMD
turmas_imd = merge_turmas_disciplinas[merge_turmas_disciplinas.codigo.str.contains("IMD")]

# utilizar apenas disciplinas com código "CONSOLIDADA"
turmas_imd = turmas_imd[turmas_imd.situacao_turma == 'CONSOLIDADA']

# Adaptar o nome da coluna id_docente_interno para id_servidor
turmas_imd.rename(columns={'id_docente_interno': 'id_servidor'}, inplace=True)

turmas_imd.capacidade_aluno = turmas_imd.capacidade_aluno.astype(np.int64)

# Adaptar os tipos de dados em turmas_imd para o merge com o dataframe docentes
turmas_imd.id_servidor = turmas_imd.id_servidor.astype(np.int64)

# %%
# filtrando as turmas com código IMD
turmas_imd2 = merge_turmas_disciplinas2[merge_turmas_disciplinas2.codigo.str.contains("IMD")]

# utilizar apenas disciplinas com código "CONSOLIDADA"
turmas_imd2 = turmas_imd2[turmas_imd2.situacao_turma == 'CONSOLIDADA']

# Adaptar o nome da coluna id_docente_interno para id_servidor
turmas_imd2.rename(columns={'id_docente_interno': 'id_servidor'}, inplace=True)

turmas_imd2.capacidade_aluno = turmas_imd2.capacidade_aluno.astype(np.int64)

# Adaptar os tipos de dados em turmas_imd para o merge com o dataframe docentes
turmas_imd2.id_servidor = turmas_imd2.id_servidor.astype(np.int64)

# %%
# filtrando as turmas com código IMD
turmas_imd3 = merge_turmas_disciplinas3[merge_turmas_disciplinas3.codigo.str.contains("IMD")]

# utilizar apenas disciplinas com código "CONSOLIDADA"
turmas_imd3 = turmas_imd3[turmas_imd3.situacao_turma == 'CONSOLIDADA']

# Adaptar o nome da coluna id_docente_interno para id_servidor
turmas_imd3.rename(columns={'id_docente_interno': 'id_servidor'}, inplace=True)

turmas_imd3.capacidade_aluno = turmas_imd3.capacidade_aluno.astype(np.int64)

# Adaptar os tipos de dados em turmas_imd para o merge com o dataframe docentes
turmas_imd3.id_servidor = turmas_imd3.id_servidor.astype(np.int64)

# %%
# filtrando as turmas com código IMD
turmas_imd4 = merge_turmas_disciplinas4[merge_turmas_disciplinas4.codigo.str.contains("IMD")]

# utilizar apenas disciplinas com código "CONSOLIDADA"
turmas_imd4 = turmas_imd4[turmas_imd4.situacao_turma == 'CONSOLIDADA']

# Adaptar o nome da coluna id_docente_interno para id_servidor
turmas_imd4.rename(columns={'id_docente_interno': 'id_servidor'}, inplace=True)

turmas_imd4.capacidade_aluno = turmas_imd4.capacidade_aluno.astype(np.int64)

# Adaptar os tipos de dados em turmas_imd para o merge com o dataframe docentes
turmas_imd4.id_servidor = turmas_imd4.id_servidor.astype(np.int64)

# %%
# filtrando as turmas com código IMD
turmas_imd5 = merge_turmas_disciplinas5[merge_turmas_disciplinas5.codigo.str.contains("IMD")]

# utilizar apenas disciplinas com código "CONSOLIDADA"
turmas_imd5 = turmas_imd5[turmas_imd5.situacao_turma == 'CONSOLIDADA']

# Adaptar o nome da coluna id_docente_interno para id_servidor
turmas_imd5.rename(columns={'id_docente_interno': 'id_servidor'}, inplace=True)

turmas_imd5.capacidade_aluno = turmas_imd5.capacidade_aluno.astype(np.int64)

# Adaptar os tipos de dados em turmas_imd para o merge com o dataframe docentes
turmas_imd5.id_servidor = turmas_imd5.id_servidor.astype(np.int64)

# %%
# filtrando as turmas com código IMD
turmas_imd6 = merge_turmas_disciplinas6[merge_turmas_disciplinas6.codigo.str.contains("IMD")]

# utilizar apenas disciplinas com código "CONSOLIDADA"
turmas_imd6 = turmas_imd6[turmas_imd6.situacao_turma == 'CONSOLIDADA']

# Adaptar o nome da coluna id_docente_interno para id_servidor
turmas_imd6.rename(columns={'id_docente_interno': 'id_servidor'}, inplace=True)

turmas_imd6.capacidade_aluno = turmas_imd6.capacidade_aluno.astype(np.int64)

# Adaptar os tipos de dados em turmas_imd para o merge com o dataframe docentes
turmas_imd6.id_servidor = turmas_imd6.id_servidor.astype(np.int64)

# %%
# merge os dataframes  turmas_imd e docentes utilizando como base a coluna id_servidor

colunns = ["id_turma", "codigo", "nivel_ensino", "nome_y",
          "nome_x","capacidade_aluno", "descricao_horario"]
turmas_imd_nomesprof = pd.merge(turmas_imd, docentes, on='id_servidor')[colunns]
lista_prof = turmas_imd_nomesprof.nome_y.unique()

# %%
# merge os dataframes  turmas_imd e docentes utilizando como base a coluna id_servidor
turmas_imd_nomesprof2 = pd.merge(turmas_imd2, docentes, on='id_servidor')[colunns]
lista_prof2 = turmas_imd_nomesprof2.nome_y.unique()

# %%
# merge os dataframes  turmas_imd e docentes utilizando como base a coluna id_servidor

turmas_imd_nomesprof3 = pd.merge(turmas_imd3, docentes, on='id_servidor')[colunns]
lista_prof3 = turmas_imd_nomesprof3.nome_y.unique()

# %%
# merge os dataframes  turmas_imd e docentes utilizando como base a coluna id_servidor

turmas_imd_nomesprof4 = pd.merge(turmas_imd4, docentes, on='id_servidor')[colunns]
lista_prof4 = turmas_imd_nomesprof4.nome_y.unique()

# %%
# merge os dataframes  turmas_imd e docentes utilizando como base a coluna id_servidor

turmas_imd_nomesprof5 = pd.merge(turmas_imd5, docentes, on='id_servidor')[colunns]
lista_prof5 = turmas_imd_nomesprof5.nome_y.unique()

# %%
# merge os dataframes  turmas_imd e docentes utilizando como base a coluna id_servidor

turmas_imd_nomesprof6 = pd.merge(turmas_imd6, docentes, on='id_servidor')[colunns]
lista_prof6 = turmas_imd_nomesprof6.nome_y.unique()

# %%
lista_prof.sort()

lista_prof2.sort()

lista_prof3.sort()

lista_prof4.sort()

lista_prof5.sort()

lista_prof6.sort()

# %%
avaliacao = pd.read_csv("avaliacaodocencia.csv", sep=';')
av_imd = avaliacao[avaliacao['nome_docente'].isin(lista_prof)]
av_imd2 = avaliacao[avaliacao['nome_docente'].isin(lista_prof2)]
av_imd3 = avaliacao[avaliacao['nome_docente'].isin(lista_prof3)]
av_imd4 = avaliacao[avaliacao['nome_docente'].isin(lista_prof4)]
av_imd5 = avaliacao[avaliacao['nome_docente'].isin(lista_prof5)]
av_imd6 = avaliacao[avaliacao['nome_docente'].isin(lista_prof6)]

# %%
av_imd_nomesprof = pd.merge(av_imd, turmas_imd, on='id_turma')

av_imd_nomesprof2 = pd.merge(av_imd, turmas_imd2, on='id_turma')

av_imd_nomesprof3 = pd.merge(av_imd3, turmas_imd3, on='id_turma')

av_imd_nomesprof4 = pd.merge(av_imd4, turmas_imd4, on='id_turma')

av_imd_nomesprof5 = pd.merge(av_imd5, turmas_imd5, on='id_turma')

av_imd_nomesprof6 = pd.merge(av_imd6, turmas_imd6, on='id_turma')

# %%
#Concatena os semestres
av_imd_nomesprof_all = pd.concat([av_imd_nomesprof, av_imd_nomesprof2, av_imd_nomesprof3, av_imd_nomesprof4,
                                 av_imd_nomesprof5, av_imd_nomesprof6])
#Concatena a lista dos professores
lista_prof_all = np.concatenate([lista_prof, lista_prof2, lista_prof3, lista_prof4, lista_prof5, lista_prof6])
lista_prof_all.sort()

# %%
av_imd_nomesprof_all['avaliacao completa'] = (av_imd_nomesprof_all['postura_profissional_media']+ av_imd_nomesprof_all['atuacao_profissional_media'])/2
av_imd_nomesprof_all.sort_values(by='avaliacao completa',ascending=True)
# Out:
#      id_docente                             nome_docente  id_turma   ano  \
# 16      5752721                              FELIPE BOHN   1220370  2014
# 86        25847              CICERO FLAVIO SOARES ARAGAO   1241130  2015
# 84        25847              CICERO FLAVIO SOARES ARAGAO   1241130  2015
# 85        25847              CICERO FLAVIO SOARES ARAGAO   1241130  2015
# 3         20904                 CARLSON PEREIRA DE SOUZA  57565320  2015
# 6         23906                   ADA CRISTINA SCUDELARI  57565375  2015
# 7         23906                   ADA CRISTINA SCUDELARI  57565375  2015
# 8         26012   MARCIA JACYNTHA NUNES RODRIGUES LUCENA  57587373  2016
# 15      5752721                              FELIPE BOHN   1220367  2014
# 114     5753090    KEITY MARA FERREIRA DE SOUZA E SABOYA   1241655  2015
# 1         18387                    MARTA MARIA DE ARAUJO   1241642  2015
# 48      5756813      RAFAELA HORACINA SILVA ROCHA SOARES  57586395  2016
# 28      5755872               SAMYR SILVA BEZERRA JACOME  57586333  2016
# 22        64329           MARCIA REGINA DA SILVA PEDRINI  57565307  2015
# 2         17907        LEONARDO FLAMARION MARQUES CHAVES  57565187  2015
# 8         23832                        JOSE BRANDAO NETO   1240964  2015
# 42      5753054                   LUCIANA SILVA CARNEIRO  57565295  2015
# 6         23193         VALDENIDES CABRAL DE ARAUJO DIAS   1243956  2015
# 3         21975              JORGE LUIZ MARIANO DA SILVA   1241641  2015
# 29        23832                        JOSE BRANDAO NETO   1240969  2015
# 28        23832                        JOSE BRANDAO NETO   1240969  2015
# 27        23832                        JOSE BRANDAO NETO   1240969  2015
# 48         2             37                        7.31
# 28         2             40                        8.02
# 22         2             16                        9.29
# 2          2             32                        7.92
# 8          1             58                        8.69
# 42         2             38                        9.31
# 6          1             25                        8.15
# 3          1             27                        9.15
# 29         1             10                        9.13
# 28         1             10                        9.13
# 27         1             10                        9.13
# 1          2             49                        8.79
# 26         1             10                        9.13
# 21         1             28                        9.08
# 37         1             10                        9.17
# 36         1             10                        9.17
# 35         1             10                        9.17
# 34         1             10                        9.17
# 23         1             27                        9.00
# ..       ...            ...                         ...
# 49         1             30                        9.95
# 48         1             30                        9.95
# 47         1             30                        9.95
# 77         2             16                        9.86
# 73         2             22                        9.87
# 44         1              6                        9.90
# 59         2             19                        9.92
# 30         2             15                        9.82
# 39         2             14                        9.96
# 40         2             14                        9.96
# 43         1              6                        9.90
# 38         2             15                        9.86
# 42         1              6                        9.90
# 45         1              6                        9.90
# 76         2             15                       10.00
# 28         2             40                        9.92
# 17         2             25                        9.92
# 29         2             40                        9.91
# 16         2             25                        9.92
# 58         2             33                        9.97
# 26         2             11                       10.00
# 63         2              5                       10.00
# 54         2              5                       10.00
# 56         2             40                       10.00
# 115        1             10                       10.00
# 39         2             16                        9.92
# 131        1             11                       10.00
# 132        1             11                       10.00
# 57         2              8                       10.00
# 58         2              8                       10.00
#
#      postura_profissional_DP  atuacao_profissional_media  \
# 16                      2.27                        5.38
# 86                      2.55                        5.23
# 84                      2.55                        5.23
# 85                      2.55                        5.23
# 3                       3.08                        7.19
# 6                       2.98                        6.34
# 7                       2.98                        6.34
# 8                       2.67                        7.29
# 15                      1.75                        6.22
# 114                     2.70                        7.97
# 1                       2.34                        6.59
# 48                      2.85                        8.80
# 28                      2.18                        8.19
# 22                      1.05                        7.04
# 2                       1.58                        8.52
# 8                       2.43                        7.86
# 42                      1.32                        7.39
# 6                       2.32                        8.56
# 3                       1.18                        7.70
# 29                      1.89                        7.73
# 28                      1.89                        7.73
# 27                      1.89                        7.73
# 1                       1.55                        8.07
# 26                      1.89                        7.73
# 21                      1.35                        7.84
# 37                      1.04                        7.76
# 36                      1.04                        7.76
# 35                      1.04                        7.76
# 34                      1.04                        7.76
# 23                      1.38                        8.13
# ..                       ...                         ...
# 49                      0.29                        9.66
# 48                      0.29                        9.66
# 47                      0.29                        9.66
# 77                      0.47                        9.76
# 73                      0.57                        9.77
# 44                      0.32                        9.75
# 59                      0.27                        9.75
# 30                      0.48                        9.86
# 39                      0.20                        9.72
# 40                      0.20                        9.72
# 43                      0.32                        9.78
# 38                      0.59                        9.83
# 42                      0.32                        9.83
# 45                      0.32                        9.83
# 76                      0.00                        9.73
# 28                      0.35                        9.82
# 17                      0.28                        9.83
# 29                      0.37                        9.84
# 16                      0.28                        9.83
# 58                      0.16                        9.80
# 26                      0.00                        9.78
# 63                      0.00                        9.78
# 54                      0.00                        9.78
# 56                      0.00                        9.79
# 115                     0.00                        9.83
# 39                      0.39                        9.97
# 131                     0.00                        9.97
# 132                     0.00                        9.97
# 57                      0.00                       10.00
# 58                      0.00                       10.00
#
#      atuacao_profissional_DP        ...          autoavaliacao_aluno_DP  \
# 16                      3.76        ...                            2.96
# 86                      3.82        ...                            0.87
# 84                      3.82        ...                            0.87
# 85                      3.82        ...                            0.87
# 3                       3.07        ...                            1.96
# 6                       3.67        ...                            3.10
# 7                       3.67        ...                            3.10
# 8                       2.96        ...                            3.31
# 15                      3.63        ...                            3.42
# 114                     2.54        ...                            2.24
# 1                       3.55        ...                            2.06
# 48                      1.80        ...                            2.24
# 28                      2.26        ...                            3.04
# 22                      3.00        ...                            1.60
# 2                       1.75        ...                            2.00
# 8                       2.76        ...                            1.86
# 42                      2.95        ...                            2.23
# 6                       1.88        ...                            1.40
# 3                       2.48        ...                            2.00
# 29                      2.45        ...                            1.62
# 28                      2.45        ...                            1.62
# 27                      2.45        ...                            1.62
# 1                       2.26        ...                            2.59
# 26                      2.45        ...                            1.62
# 21                      2.87        ...                            2.17
# 37                      2.47        ...                            1.66
# 36                      2.47        ...                            1.66
# 35                      2.47        ...                            1.66
# 34                      2.47        ...                            1.66
# 23                      1.96        ...                            2.20
# ..                       ...        ...                             ...
# 49                      0.83        ...                            2.04
# 48                      0.83        ...                            2.04
# 47                      0.83        ...                            2.04
# 77                      0.61        ...                            1.85
# 73                      0.76        ...                            2.15
# 44                      0.49        ...                            0.36
# 59                      0.65        ...                            1.47
# 30                      0.50        ...                            1.41
# 39                      0.76        ...                            1.18
# 40                      0.76        ...                            1.18
# 43                      0.42        ...                            0.32
# 38                      0.57        ...                            1.88
# 42                      0.38        ...                            0.50
# 45                      0.50        ...                            0.36
# 76                      0.67        ...                            2.24
# 28                      0.59        ...                            1.40
# 17                      0.57        ...                            1.70
# 29                      0.53        ...                            1.43
# 16                      0.57        ...                            1.70
# 58                      0.87        ...                            2.96
# 26                      0.72        ...                            2.37
# 63                      0.77        ...                            0.37
# 54                      0.58        ...                            0.81
# 56                      0.57        ...                            2.17
# 115                     0.38        ...                            1.19
# 39                      0.17        ...                            1.76
# 131                     0.24        ...                            1.67
# 132                     0.24        ...                            1.67
# 57                      0.00        ...                            0.00
# 58                      0.00        ...                            0.00
#
#      id_servidor     codigo nivel_ensino  \
# 16       5752721    IMD0106    GRADUAÇÃO
# 86         25847    IMD0033    GRADUAÇÃO
# 84       5756808    IMD0030    GRADUAÇÃO
# 85       5752189    IMD0030    GRADUAÇÃO
# 3          20904    IMD0034    GRADUAÇÃO
# 6        5757248    IMD0030    GRADUAÇÃO
# 7          23906    IMD0033    GRADUAÇÃO
# 8          26012    IMD0401    GRADUAÇÃO
# 15       5752721    IMD0105    GRADUAÇÃO
# 114      5753090    IMD0036    GRADUAÇÃO
# 1          18387    IMD0321    GRADUAÇÃO
# 48       5756813    IMD0033    GRADUAÇÃO
# 28       5755872    IMD0034    GRADUAÇÃO
# 22         64329    IMD0028    GRADUAÇÃO
# 2          17907    IMD0018    GRADUAÇÃO
# 8        5752029    IMD0020    GRADUAÇÃO
# 42       5753054    IMD0028    GRADUAÇÃO
# 6          23193    IMD0702    GRADUAÇÃO
# 3          21975    IMD0320    GRADUAÇÃO
# 29         22053  IMD0012.1    GRADUAÇÃO
# 28       5752647  IMD0012.1    GRADUAÇÃO
# 27         23832  IMD0012.0    GRADUAÇÃO
# 1          15423    IMD0040    GRADUAÇÃO
# 26       5752029  IMD0012.0    GRADUAÇÃO
# 21       5755421    IMD0029    GRADUAÇÃO
# 37         22053  IMD0012.1    GRADUAÇÃO
# 36       5752647  IMD0012.1    GRADUAÇÃO
# 35         23832  IMD0012.0    GRADUAÇÃO
# 34       5752029  IMD0012.0    GRADUAÇÃO
# 23       5755421    IMD0029    GRADUAÇÃO
# ..           ...        ...          ...
# 49       5755453    IMD0044    GRADUAÇÃO
# 48       5756689    IMD0040    GRADUAÇÃO
# 47       5753754    IMD0040    GRADUAÇÃO
# 77       5757883    IMD0412    GRADUAÇÃO
# 73       5757620    IMD0502    GRADUAÇÃO
# 44         24826    IMD0029    GRADUAÇÃO
# 59       5757088    IMD0518    GRADUAÇÃO
# 30       5752798    IMD0017    GRADUAÇÃO
# 39       5752990  IMD0012.0    GRADUAÇÃO
# 40       5757238  IMD0012.0    GRADUAÇÃO
# 43         24826    IMD0029    GRADUAÇÃO
# 38       5757238  IMD0012.0    GRADUAÇÃO
# 42         24826    IMD0029    GRADUAÇÃO
# 45         24826    IMD0029    GRADUAÇÃO
# 76       5757883    IMD0029    GRADUAÇÃO
# 28       5751875    IMD0017    GRADUAÇÃO
# 17       5757669  IMD0012.1    GRADUAÇÃO
# 29       5751875    IMD0017    GRADUAÇÃO
# 16         25889  IMD0012.0    GRADUAÇÃO
# 58       5757075    IMD0044    GRADUAÇÃO
# 26       5755871    IMD0036    GRADUAÇÃO
# 63       5757369    IMD0319    GRADUAÇÃO
# 54       5755039    IMD0029    GRADUAÇÃO
# 56       5757071    IMD0039    GRADUAÇÃO
# 115      5753098    IMD0510    GRADUAÇÃO
# 39       5756342    IMD0411    GRADUAÇÃO
# 131      5756808    IMD0044    GRADUAÇÃO
# 132      5756980    IMD0105    GRADUAÇÃO
# 57       5757766    IMD0704    GRADUAÇÃO
# 58       5757766    IMD0704    GRADUAÇÃO
#
#                                                   nome  \
# 16   TÓPICOS ESPECIAIS EM TECNOLOGIA DA INFORMAÇÃO VII
# 86                                       PROBABILIDADE
# 84                          LINGUAGEM DE PROGRAMAÇÃO I
# 85                          LINGUAGEM DE PROGRAMAÇÃO I
# 3                        VETORES E GEOMETRIA ANALÍTICA
# 6                           LINGUAGEM DE PROGRAMAÇÃO I
# 7                                        PROBABILIDADE
# 8                                       BANCO DE DADOS
# 15    TÓPICOS ESPECIAIS EM TECNOLOGIA DA INFORMAÇÃO VI
# 114                              SISTEMAS OPERACIONAIS
# 1              PROJETOS BASEADOS EM MICROCONTROLADORES
# 48                                       PROBABILIDADE
# 28                       VETORES E GEOMETRIA ANALÍTICA
# 22             FUNDAMENTOS MATEMÁTICOS DA COMPUTAÇÃO I
# 2                        PRÁTICAS DE LEITURA EM INGLÊS
# 8                 TECNOLOGIA DA INFORMAÇÃO E SOCIEDADE
# 42             FUNDAMENTOS MATEMÁTICOS DA COMPUTAÇÃO I
# 6                        SERVIÇOS DE REDE E TRANSPORTE
# 3                                CIRCUITOS ELETRÔNICOS
# 29                 PRÁTICAS DE TÉCNICAS DE PROGRAMAÇÃO
# 28                 PRÁTICAS DE TÉCNICAS DE PROGRAMAÇÃO
# 27               INTRODUÇÃO ÀS TÉCNICAS DE PROGRAMAÇÃO
# 1                          LINGUAGEM DE PROGRAMAÇÃO II
# 26               INTRODUÇÃO ÀS TÉCNICAS DE PROGRAMAÇÃO
# 21                        ESTRUTURA DE DADOS BÁSICAS I
# 37                 PRÁTICAS DE TÉCNICAS DE PROGRAMAÇÃO
# 36                 PRÁTICAS DE TÉCNICAS DE PROGRAMAÇÃO
# 35               INTRODUÇÃO ÀS TÉCNICAS DE PROGRAMAÇÃO
# 34               INTRODUÇÃO ÀS TÉCNICAS DE PROGRAMAÇÃO
# 23                        ESTRUTURA DE DADOS BÁSICAS I
# ..                                                 ...
# 49             PRÁTICAS DE LEITURA E ESCRITA EM INGLÊS
# 48                         LINGUAGEM DE PROGRAMAÇÃO II
# 47                         LINGUAGEM DE PROGRAMAÇÃO II
# 77                     INTRODUÇÃO AO TESTE DE SOFTWARE
# 73   PROCESSO DE DESENVOLVIMENTO DE SOFTWARE EDUCAC...
# 44                        ESTRUTURA DE DADOS BÁSICAS I
# 59   FUNDAMENTOS PEDAGÓGICOS PARA A INFORMÁTICA EDU...
# 30        PRÁTICAS DE LEITURA E ESCRITA EM PORTUGUÊS I
# 39               INTRODUÇÃO ÀS TÉCNICAS DE PROGRAMAÇÃO
# 40               INTRODUÇÃO ÀS TÉCNICAS DE PROGRAMAÇÃO
# 43                        ESTRUTURA DE DADOS BÁSICAS I
# 38               INTRODUÇÃO ÀS TÉCNICAS DE PROGRAMAÇÃO
# 42                        ESTRUTURA DE DADOS BÁSICAS I
# 45                        ESTRUTURA DE DADOS BÁSICAS I
# 76                        ESTRUTURA DE DADOS BÁSICAS I
# 28        PRÁTICAS DE LEITURA E ESCRITA EM PORTUGUÊS I
# 17                 PRÁTICAS DE TÉCNICAS DE PROGRAMAÇÃO
# 29        PRÁTICAS DE LEITURA E ESCRITA EM PORTUGUÊS I
# 16               INTRODUÇÃO ÀS TÉCNICAS DE PROGRAMAÇÃO
# 58             PRÁTICAS DE LEITURA E ESCRITA EM INGLÊS
# 26                               SISTEMAS OPERACIONAIS
# 63                       TEORIA DE CIRCUITOS ELÉTRICOS
# 54                        ESTRUTURA DE DADOS BÁSICAS I
# 56                      ESTRUTURAS DE DADOS BÁSICAS II
# 115                             ACESSIBILIDADE DIGITAL
# 39              INTRODUÇÃO À GOVERNANÇA E GESTÃO DE TI
# 131            PRÁTICAS DE LEITURA E ESCRITA EM INGLÊS
# 132   TÓPICOS ESPECIAIS EM TECNOLOGIA DA INFORMAÇÃO VI
# 57    ADMINISTRAÇÃO DE SERVIÇOS DE REDES PARA INTERNET
# 58    ADMINISTRAÇÃO DE SERVIÇOS DE REDES PARA INTERNET
#
#              unidade_responsavel situacao_turma capacidade_aluno  \
# 16   INSTITUTO METROPOLE DIGITAL    CONSOLIDADA               32
# 86   INSTITUTO METROPOLE DIGITAL    CONSOLIDADA               16
# 84   INSTITUTO METROPOLE DIGITAL    CONSOLIDADA               16
# 85   INSTITUTO METROPOLE DIGITAL    CONSOLIDADA               16
# 3    INSTITUTO METROPOLE DIGITAL    CONSOLIDADA               20
# 6    INSTITUTO METROPOLE DIGITAL    CONSOLIDADA               40
# 7    INSTITUTO METROPOLE DIGITAL    CONSOLIDADA               40
# 8    INSTITUTO METROPOLE DIGITAL    CONSOLIDADA               25
# 15   INSTITUTO METROPOLE DIGITAL    CONSOLIDADA               32
# 114  INSTITUTO METROPOLE DIGITAL    CONSOLIDADA               57
# 1    INSTITUTO METROPOLE DIGITAL    CONSOLIDADA               50
# 48   INSTITUTO METROPOLE DIGITAL    CONSOLIDADA               60
# 28   INSTITUTO METROPOLE DIGITAL    CONSOLIDADA               65
# 22   INSTITUTO METROPOLE DIGITAL    CONSOLIDADA               40
# 2    INSTITUTO METROPOLE DIGITAL    CONSOLIDADA               32
# 8    INSTITUTO METROPOLE DIGITAL    CONSOLIDADA               60
# 42   INSTITUTO METROPOLE DIGITAL    CONSOLIDADA               40
# 6    INSTITUTO METROPOLE DIGITAL    CONSOLIDADA               45
# 3    INSTITUTO METROPOLE DIGITAL    CONSOLIDADA               52
# 29   INSTITUTO METROPOLE DIGITAL    CONSOLIDADA               12
# 28   INSTITUTO METROPOLE DIGITAL    CONSOLIDADA               12
# 27   INSTITUTO METROPOLE DIGITAL    CONSOLIDADA               12
# 1    INSTITUTO METROPOLE DIGITAL    CONSOLIDADA               51
# 26   INSTITUTO METROPOLE DIGITAL    CONSOLIDADA               12
# 21   INSTITUTO METROPOLE DIGITAL    CONSOLIDADA               35
# 37   INSTITUTO METROPOLE DIGITAL    CONSOLIDADA               12
# 36   INSTITUTO METROPOLE DIGITAL    CONSOLIDADA               12
# 35   INSTITUTO METROPOLE DIGITAL    CONSOLIDADA               12
# 34   INSTITUTO METROPOLE DIGITAL    CONSOLIDADA               12
# 23   INSTITUTO METROPOLE DIGITAL    CONSOLIDADA               35
# ..                           ...            ...              ...
# 49   INSTITUTO METROPOLE DIGITAL    CONSOLIDADA               32
# 48   INSTITUTO METROPOLE DIGITAL    CONSOLIDADA               32
# 47   INSTITUTO METROPOLE DIGITAL    CONSOLIDADA               32
# 77   INSTITUTO METROPOLE DIGITAL    CONSOLIDADA               40
# 73   INSTITUTO METROPOLE DIGITAL    CONSOLIDADA               60
# 44   INSTITUTO METROPOLE DIGITAL    CONSOLIDADA                6
# 59   INSTITUTO METROPOLE DIGITAL    CONSOLIDADA               40
# 30   INSTITUTO METROPOLE DIGITAL    CONSOLIDADA               16
# 39   INSTITUTO METROPOLE DIGITAL    CONSOLIDADA               15
# 40   INSTITUTO METROPOLE DIGITAL    CONSOLIDADA               15
# 43   INSTITUTO METROPOLE DIGITAL    CONSOLIDADA                6
# 38   INSTITUTO METROPOLE DIGITAL    CONSOLIDADA               15
# 42   INSTITUTO METROPOLE DIGITAL    CONSOLIDADA                6
# 45   INSTITUTO METROPOLE DIGITAL    CONSOLIDADA                6
# 76   INSTITUTO METROPOLE DIGITAL    CONSOLIDADA               40
# 28   INSTITUTO METROPOLE DIGITAL    CONSOLIDADA               40
# 17   INSTITUTO METROPOLE DIGITAL    CONSOLIDADA               61
# 29   INSTITUTO METROPOLE DIGITAL    CONSOLIDADA               40
# 16   INSTITUTO METROPOLE DIGITAL    CONSOLIDADA               61
# 58   INSTITUTO METROPOLE DIGITAL    CONSOLIDADA               60
# 26   INSTITUTO METROPOLE DIGITAL    CONSOLIDADA               40
# 63   INSTITUTO METROPOLE DIGITAL    CONSOLIDADA                7
# 54   INSTITUTO METROPOLE DIGITAL    CONSOLIDADA               40
# 56   INSTITUTO METROPOLE DIGITAL    CONSOLIDADA               45
# 115  INSTITUTO METROPOLE DIGITAL    CONSOLIDADA               13
# 39   INSTITUTO METROPOLE DIGITAL    CONSOLIDADA               40
# 131  INSTITUTO METROPOLE DIGITAL    CONSOLIDADA               12
# 132  INSTITUTO METROPOLE DIGITAL    CONSOLIDADA               12
# 57   INSTITUTO METROPOLE DIGITAL    CONSOLIDADA                8
# 58   INSTITUTO METROPOLE DIGITAL    CONSOLIDADA                8
#
#                               descricao_horario avaliacao completa
# 16        5M56  46T56 (27/01/2014 - 14/06/2014)              6.505
# 86                                  5T564 6T123              6.825
# 84                                  5T564 6T123              6.825
# 85                                  5T564 6T123              6.825
# 3                                          6T54              6.860
# 6                                         35T56              6.950
# 7                                         35T56              6.950
# 8               35M34 (25/07/2016 - 17/12/2016)              7.540
# 15        4M34  46T56 (27/01/2014 - 14/06/2014)              7.590
# 114                                       24N12              7.625
# 1                                        35T123              7.665
# 48              24N12 (25/07/2016 - 17/12/2016)              8.055
# 28              24T34 (25/07/2016 - 17/12/2016)              8.105
# 22                                        35N34              8.165
# 2                                         35T34              8.220
# 8                                           3M3              8.275
# 42                                       4M3456              8.350
# 6                                        6N1234              8.355
# 3                                         35M34              8.425
# 29              56M34 (02/02/2015 - 20/06/2015)              8.430
# 28              56M34 (02/02/2015 - 20/06/2015)              8.430
# 27              56M34 (02/02/2015 - 20/06/2015)              8.430
# 1                                         46N12              8.430
# 26              56M34 (02/02/2015 - 20/06/2015)              8.430
# 21        2M56  35T12 (27/01/2014 - 14/06/2014)              8.460
# 37              56M34 (02/02/2015 - 20/06/2015)              8.465
# 36              56M34 (02/02/2015 - 20/06/2015)              8.465
# 35              56M34 (02/02/2015 - 20/06/2015)              8.465
# 34              56M34 (02/02/2015 - 20/06/2015)              8.465
# 23        6M34  35T12 (27/01/2014 - 14/06/2014)              8.565
# ..                                          ...                ...
# 49        3M56  46T56 (27/01/2014 - 14/06/2014)              9.805
# 48        3M56  46T56 (27/01/2014 - 14/06/2014)              9.805
# 47        3M56  46T56 (27/01/2014 - 14/06/2014)              9.805
# 77              35N12 (25/07/2016 - 17/12/2016)              9.810
# 73              35N12 (25/07/2016 - 17/12/2016)              9.820
# 44              24T12 (02/02/2015 - 20/06/2015)              9.825
# 59              24N34 (25/07/2016 - 17/12/2016)              9.835
# 30                                        24N34              9.840
# 39                                2M234 5M23456              9.840
# 40                                2M234 5M23456              9.840
# 43              24T12 (02/02/2015 - 20/06/2015)              9.840
# 38                                2M234 3M23456              9.845
# 42              24T12 (02/02/2015 - 20/06/2015)              9.865
# 45              24T12 (02/02/2015 - 20/06/2015)              9.865
# 76              35N34 (25/07/2016 - 17/12/2016)              9.865
# 28                                        35M34              9.870
# 17           246N1234 (27/07/2015 - 19/12/2015)              9.875
# 29                                        35M34              9.875
# 16           246N1234 (27/07/2015 - 19/12/2015)              9.875
# 58              35T34 (25/07/2016 - 17/12/2016)              9.885
# 26              24N34 (25/07/2016 - 17/12/2016)              9.890
# 63   5M123456  3T1234 (15/10/2015 - 29/10/2015)              9.890
# 54                                       345N12              9.890
# 56              35N34 (25/07/2016 - 17/12/2016)              9.895
# 115             3T123 (02/02/2015 - 20/06/2015)              9.915
# 39              35N12 (25/07/2016 - 17/12/2016)              9.945
# 131                                       2T564              9.985
# 132                                       2T564              9.985
# 57     2M23456  6T456 (12/10/2015 - 06/11/2015)             10.000
# 58     2M23456  6T456 (12/10/2015 - 06/11/2015)             10.000
#
# [343 rows x 21 columns]

# %%
from __future__ import print_function
from ipywidgets import interact, interactive, fixed, interact_man
AMIANA CLEUMA DE MEDEIROS', 'DANIEL MARQUES DE ALMEIDA PESSOA', 'DANIELLE SOARES BEZERRA', 'DANILO CURVELO DE SOUZA', 'DAVID MENDES', 'DENNYS LEITE MAIA', 'DEUSIMAR FREIRE BRASIL', 'DIEGO ANDRES LAPLAGNE', 'DIEGO DE SOUSA DANTAS', 'DINARA LESLYE MACEDO E SILVA CALAZANS', 'DIOGENES FELIX DA SILVA COSTA', 'DIOMADSON RODRIGUES BELFORT', 'DJALMA RIBEIRO DA SILVA', 'EDGARD DE FARIA CORREA', 'EDMILSON JOVINO DE OLIVEIRA', 'EDMILSON PINTO ALBUQUERQUE', 'EDNA MARIA RANGEL DE SA', 'EDUARDO NOGUEIRA CUNHA', 'EIJI ADACHI MEDEIROS BARBOSA', 'ELAINE CRISTINA GAVIOLI', 'ELIZA MARIA XAVIER FREIRE', 'ENIO CAMPOS AMICO', 'ERIVAN FERREIRA BORGES', 'EULER MACIEL DANTAS', 'EULER MACIEL DANTAS', 'EUZEBIO GUIMARAES BARBOSA', 'EUZEBIO GUIMARAES BARBOSA', 'EVERALDO SILVINO DOS SANTOS', 'EVERTON RANIELLY DE SOUSA CAVALCANTE', 'EZEQUIAS OLIVEIRA LIRA', 'FABIANA BARBOSA GONCALVES', 'FABIANA CRISTINA MENDONCA DE ARAUJO', 'FABIANA LIMA BEZERRA', 'FABIANA TRISTAO DE SANTANA', 'FABIO DE ALMEIDA VIEIRA', 'FABIO MAFRA BORGES', 'FABIO ROBERTO DAMETTO', 'FABIO SPEROTTO BEMFICA', 'FABRICIO PITOMBO LEITE', 'FELIPE BOHN', 'FERNANDA DA FONSECA FREITAS', 'FERNANDA DINIZ DE SA', 'FERNANDO HENRIQUE ANDRADE NOGUEIRA', 'FLAVIO EDUARDO FALCAO LEMOS', 'FLAVIO MEDEIROS JUNIOR', 'FRANCISCA IDANESIA DA SILVA', 'FRANCISCO NABUCO DE ALMEIDA BARRETO NETO', 'GERLANE COELHO BERNARDO GUERRA', 'GIBEON SOARES DE AQUINO JUNIOR', 'GILMAR AMORIM DE SOUSA', 'GILSON DE VASCONCELOS TORRES', 'GISELLE COSTA DE SOUSA', 'GISLENE MARIA DA SILVA GANADE', 'GLEYDSON PINHEIRO ALBANO', 'GUILHERME AUGUSTO DE FREITAS FREGONEZI', 'GUSTAVO AUGUSTO SEABRA BARBOSA', 'GUSTAVO AUGUSTO SEABRA BARBOSA', 'GUSTAVO GIRAO BARRETO DA SILVA', 'HAILSON ALVES FERREIRA PRESTON', 'HECTOR LENY CARRION SALAZAR', 'HELCIO PACHECO DE MEDEIROS', 'HELDER ALEXANDRE MEDEIROS DE MACEDO', 'HERNANI DE PAIVA GADELHA JUNIOR', 'HUGO ALEXANDRE DE OLIVEIRA ROCHA', 'IDIVALDO ANTONIO MICAL ...

# %%
% matplotlib inline
from ipywidgets import interactive
import matplotlib.pyplot as plt
import numpy as np

def evolucaoGrafico(x):
    dados_prof_all = av_imd_nomesprof_all.loc[av_imd_nomesprof_all['nome_docente'] == x]
    plt.barh(dados_prof_all['nome'],dados_prof_all['avaliacao completa'], 0.2)
    plt.xlabel("Notas")
    plt.ylabel("Disciplinas")
    plt.title("Titulo")
    plt.show()
    
interactive_plot = interact(evolucaoGrafico, x=lista_prof_all,)
interactive_plot
# Out:
# interactive(children=(Dropdown(description='x', options=('ADA CRISTINA SCUDELARI', 'ADELENA GONCALVES MAIA', 'ADILSON DE LIMA TAVARES', 'ADJA FERREIRA DE ANDRADE', 'ADRIANA ROSA CARVALHO', 'ADRIANO DOS SANTOS', 'ALEX JOSE SOUZA DOS SANTOS', 'ALEX JOSE SOUZA DOS SANTOS', 'ALEXANDRE FADIGAS DE SOUZA', 'ALEXANDRO TEIXEIRA GOMES', 'ALLAN DE MEDEIROS MARTINS', 'ALUIZIO FERREIRA DA ROCHA NETO', 'ALYSON MATHEUS DE CARVALHO SOUZA', 'AMANDA BORGES DE ALBUQUERQUE ASSUNCAO', 'ANA CRISTINA ARAUJO DE ANDRADE GALVAO', 'ANA KATHERINE DA SILVEIRA GONCALVES DE OLIVEIRA', 'ANA PATRICIA DE QUEIROZ MEDEIROS DANTAS', 'ANA PAULA BARRETO GOMES', 'ANA RAFAELA LUZ DE AQUINO MARTINS', 'ANA RAQUEL RODRIGUES LINDQUIST', 'ANDRE FERRER PINTO MARTINS', 'ANDRE LUIS CABRAL DE LOURENCO', 'ANDRE LUIS DORINI', 'ANDRE LUIS LOPES MORIYAMA', 'ANDRE LUIS PINTO SOARES', 'ANDRE LUIZ DA SILVA SOLINO', 'ANDRE LUIZ MARINHO FALCAO GONDIM', 'ANDRE MAURICIO CUNHA CAMPOS', 'ANNE CHRISTINE DAMASIO', 'ANNE CHRISTINE DAMASIO', 'ANNE MAGALY DE PAULA CANUTO', 'ANTONIO DE LISBOA LOPES COSTA', 'ANTONIO DE LISBOA LOPES COSTA', 'ANTONIO IGOR SILVA DE OLIVEIRA', 'ANTONIO RICARDO CALAZANS DUARTE', 'ANTONIO WALLACE ANTUNES SOARES', 'ATHANASIOS TSOUANAS', 'AUGUSTO JOSE VENANCIO NETO', 'AUZELIVIA PASTORA REGO MEDEIROS FALCAO', 'BONIEK CASTILLO DUTRA BORGES', 'BONIEK CASTILLO DUTRA BORGES', 'BRUNA LEAL LIMA MACIEL', 'BRUNO CESAR DE VASCONCELOS GURGEL', 'BRUNO SANTANA DA SILVA', 'CANDIDA MARIA BEZERRA DANTAS', 'CANDIDA MARIA BEZERRA DANTAS', 'CARLA ALMEIDA VIVACQUA', 'CARLOS ALBERTO ALMEIDA DE ARAUJO', 'CARLOS ALBERTO PASKOCIMAS', 'CARLOS AUGUSTO PROLO', 'CARLOS JOSE WANDERLEY FERREIRA', 'CARLOS NECO DA SILVA JUNIOR', 'CARLSON PEREIRA DE SOUZA', 'CAROLINE ADDISON CARVALHO XAVIER DE MEDEIROS', 'CAROLINE ADDISON CARVALHO XAVIER DE MEDEIROS', 'CAROLINE THENNECY DE MEDEIROS ROCHA', 'CATARINA DE OLIVEIRA SOUSA', 'CELSO LUIZ SOUZA DE OLIVEIRA', 'CESAR RENNO COSTA', 'CHARLES AN