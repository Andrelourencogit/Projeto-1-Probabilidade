# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import ipywidgets as widgets
import sys
reload(sys)
sys.setdefaultencoding('utf-8')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-0ed9bac8ee89> in <module>()
#       5 import ipywidgets as widgets
#       6 import sys
# ----> 7 reload(sys)
#       8 sys.setdefaultencoding('utf-8')
#
# NameError: name 'reload' is not defined

# %%
turmas = pd.read_csv('Dados Turma/turmas-2016.2.csv', sep=';')
disciplinas = pd.read_csv('componentes-curriculares-presenciais.csv', 
                          sep=';', 
                          usecols=["id_componente","codigo","nivel","nome","unidade_responsavel"])
docentes = pd.read_csv('docentes.csv', sep=';')

# %%
turmas.rename(columns={'id_componente_curricular': 'id_componente'}, inplace=True)
turmas.id_componente = turmas.id_componente.astype(str)

# Limpando o dataframe disciplinas com linhas desnecessárias
disciplinas.dropna(inplace=True)
disciplinas = disciplinas[~disciplinas.id_componente.duplicated()]

# %%
colunas = ["id_turma","id_docente_interno","codigo","nivel_ensino","nome","unidade_responsavel",
          "situacao_turma","capacidade_aluno","descricao_horario"]

merge_turmas_disciplinas = pd.merge(turmas, disciplinas, on='id_componente')[colunas]
merge_turmas_disciplinas.dropna(inplace=True)
merge_turmas_disciplinas.head()
# Out:
#    id_turma  id_docente_interno   codigo nivel_ensino  \
# 0  57581492           5753060.0  GPU0009   LATO SENSU
# 1  57583343           5752921.0   MUT311      TÉCNICO
# 2  57583344           5752917.0   MUT491      TÉCNICO
# 3  57583345             23400.0   MUT102      TÉCNICO
# 4  57583346             35466.0   MUT102      TÉCNICO
#
#                                        nome  \
# 0  INOVAÇÃO NA GESTÃO DE POLÍTICAS PÚBLICAS
# 1                     APRECIAÇÃO MUSICAL II
# 2                               ARRANJOS II
# 3                                  CANTO II
# 4                                  CANTO II
#
#                            unidade_responsavel situacao_turma  \
# 0  PROGRAMA DE PÓS-GRADUAÇÃO EM GESTÃO PÚBLICA    CONSOLIDADA
# 1                             ESCOLA DE MÚSICA    CONSOLIDADA
# 2                             ESCOLA DE MÚSICA    CONSOLIDADA
# 3                             ESCOLA DE MÚSICA    CONSOLIDADA
# 4                             ESCOLA DE MÚSICA    CONSOLIDADA
#
#    capacidade_aluno     descricao_horario
# 0              50.0  7M2345  35T23456 7T1
# 1              30.0                2T1234
# 2              20.0                  3T34
# 3               3.0                 3T123
# 4               3.0                 6T456

# %%
# filtrando as turmas com código IMD
turmas_imd = merge_turmas_disciplinas[merge_turmas_disciplinas.codigo.str.contains("IMD")]

# utilizar apenas disciplinas com código "CONSOLIDADA"
turmas_imd = turmas_imd[turmas_imd.situacao_turma == 'CONSOLIDADA']

# Adaptar o nome da coluna id_docente_interno para id_servidor
turmas_imd.rename(columns={'id_docente_interno': 'id_servidor'}, inplace=True)

turmas_imd.capacidade_aluno = turmas_imd.capacidade_aluno.astype(np.int64)

# Adaptar os tipos de dados em turmas_imd para o merge com o dataframe docentes
turmas_imd.id_servidor = turmas_imd.id_servidor.astype(np.int64)
turmas_imd.head()
# Out:
#       id_turma  id_servidor   codigo nivel_ensino  \
# 3564  57586177        62353  IMD0029    GRADUAÇÃO
# 3565  57586351      5757975  IMD0029    GRADUAÇÃO
# 3566  57586359      5757905  IMD0029    GRADUAÇÃO
# 3567  57586359      5757071  IMD0029    GRADUAÇÃO
# 3568  57586361      5757883  IMD0029    GRADUAÇÃO
#
#                               nome          unidade_responsavel  \
# 3564  ESTRUTURA DE DADOS BÁSICAS I  INSTITUTO METROPOLE DIGITAL
# 3565  ESTRUTURA DE DADOS BÁSICAS I  INSTITUTO METROPOLE DIGITAL
# 3566  ESTRUTURA DE DADOS BÁSICAS I  INSTITUTO METROPOLE DIGITAL
# 3567  ESTRUTURA DE DADOS BÁSICAS I  INSTITUTO METROPOLE DIGITAL
# 3568  ESTRUTURA DE DADOS BÁSICAS I  INSTITUTO METROPOLE DIGITAL
#
#      situacao_turma  capacidade_aluno                descricao_horario
# 3564    CONSOLIDADA                60  35M12 (25/07/2016 - 17/12/2016)
# 3565    CONSOLIDADA                60  35T12 (25/07/2016 - 17/12/2016)
# 3566    CONSOLIDADA                60  35N12 (25/07/2016 - 17/12/2016)
# 3567    CONSOLIDADA                60  35N12 (25/07/2016 - 17/12/2016)
# 3568    CONSOLIDADA                40  35N34 (25/07/2016 - 17/12/2016)

# %%
# merge os dataframes  turmas_imd e docentes utilizando como base a coluna id_servidor

colunas = ["id_turma", "codigo", "nivel_ensino", "nome_y",
          "nome_x","capacidade_aluno", "descricao_horario"]
turmas_imd_nomesprof = pd.merge(turmas_imd, docentes, on='id_servidor')[colunas]
lista_prof = turmas_imd_nomesprof.nome_y.unique()

# %%
lista_prof.sort()
turmas_imd_nomesprof.head()
# Out:
#    id_turma   codigo nivel_ensino                           nome_y  \
# 0  57586177  IMD0029    GRADUAÇÃO       SELAN RODRIGUES DOS SANTOS
# 1  57586198  IMD0030    GRADUAÇÃO       SELAN RODRIGUES DOS SANTOS
# 2  57586359  IMD0029    GRADUAÇÃO                CESAR RENNO COSTA
# 3  57586373  IMD0030    GRADUAÇÃO                CESAR RENNO COSTA
# 4  57586359  IMD0029    GRADUAÇÃO  JORGE ESTEFANO SANTANA DE SOUZA
#
#                          nome_x  capacidade_aluno  \
# 0  ESTRUTURA DE DADOS BÁSICAS I                60
# 1    LINGUAGEM DE PROGRAMAÇÃO I                30
# 2  ESTRUTURA DE DADOS BÁSICAS I                60
# 3    LINGUAGEM DE PROGRAMAÇÃO I                32
# 4  ESTRUTURA DE DADOS BÁSICAS I                60
#
#                  descricao_horario
# 0  35M12 (25/07/2016 - 17/12/2016)
# 1  35M34 (25/07/2016 - 17/12/2016)
# 2  35N12 (25/07/2016 - 17/12/2016)
# 3  35N34 (25/07/2016 - 17/12/2016)
# 4  35N12 (25/07/2016 - 17/12/2016)

# %%
#Essa celula pega a avaliação dos professores do imd
avaliacao = pd.read_csv("avaliacaodocencia.csv", sep=';')
av_imd = avaliacao[avaliacao['nome_docente'].isin(lista_prof)]
av_imd.head()
#avaliacao2 = (avaliacao[(avaliacao.ano.astype(str).str.contains("2016")) | (avaliacao.ano.astype(str).str.contains("2017"))]
# Out:
#        id_docente                 nome_docente  id_turma   ano  periodo  \
# 12856       24853  ANNE MAGALY DE PAULA CANUTO   1208019  2013        2
# 12857       24853  ANNE MAGALY DE PAULA CANUTO   1211641  2013        2
# 12858       24853  ANNE MAGALY DE PAULA CANUTO   1217954  2014        1
# 12859       24853  ANNE MAGALY DE PAULA CANUTO   1228386  2014        2
# 12860       24853  ANNE MAGALY DE PAULA CANUTO   1239412  2015        1
#
#        qtd_discentes  postura_profissional_media  postura_profissional_DP  \
# 12856             33                        9.43                     0.91
# 12857             12                        9.42                     0.97
# 12858             19                        9.23                     1.81
# 12859             17                        9.50                     0.83
# 12860             25                        9.25                     1.27
#
#        atuacao_profissional_media  atuacao_profissional_DP  \
# 12856                        9.27                     1.21
# 12857                        8.72                     1.80
# 12858                        7.63                     2.94
# 12859                        7.67                     2.71
# 12860                        8.78                     1.52
#
#        autoavaliacao_aluno_media  autoavaliacao_aluno_DP
# 12856                       8.64                    2.16
# 12857                       7.90                    2.55
# 12858                       7.24                    3.38
# 12859                       8.31                    2.50
# 12860                       7.87                    2.54

# %%
# merge os dataframes  av_imd e turmas_imd utilizando como base a coluna id_turma

av_imd_nomesprof = pd.merge(av_imd, turmas_imd, on='id_turma')
av_imd_nomesprof.head()
# Out:
#    id_docente                 nome_docente  id_turma   ano  periodo  \
# 0       24853  ANNE MAGALY DE PAULA CANUTO  57586394  2016        2
# 1       24949  ANDRE MAURICIO CUNHA CAMPOS  57586250  2016        2
# 2       24949  ANDRE MAURICIO CUNHA CAMPOS  57586259  2016        2
# 3       24949  ANDRE MAURICIO CUNHA CAMPOS  57586277  2016        2
# 4       25868       UMBERTO SOUZA DA COSTA  57586366  2016        2
#
#    qtd_discentes  postura_profissional_media  postura_profissional_DP  \
# 0             12                       10.00                     0.00
# 1             16                        9.46                     0.83
# 2             32                        9.25                     1.49
# 3             16                        9.50                     0.80
# 4             23                        9.88                     0.33
#
#    atuacao_profissional_media  atuacao_profissional_DP  \
# 0                        9.47                     1.14
# 1                        9.05                     1.48
# 2                        8.16                     2.83
# 3                        8.75                     1.86
# 4                        8.38                     2.35
#
#    autoavaliacao_aluno_media  autoavaliacao_aluno_DP  id_servidor     codigo  \
# 0                       7.89                    3.24        24853    IMD0033
# 1                       8.47                    2.13        24949  IMD0012.0
# 2                       8.66                    2.36        24949  IMD0012.1
# 3                       8.09                    2.79        24949  IMD0012.1
# 4                       8.57                    1.99        25868    IMD0030
#
#   nivel_ensino                                   nome  \
# 0    GRADUAÇÃO                          PROBABILIDADE
# 1    GRADUAÇÃO  INTRODUÇÃO ÀS TÉCNICAS DE PROGRAMAÇÃO
# 2    GRADUAÇÃO    PRÁTICAS DE TÉCNICAS DE PROGRAMAÇÃO
# 3    GRADUAÇÃO    PRÁTICAS DE TÉCNICAS DE PROGRAMAÇÃO
# 4    GRADUAÇÃO             LINGUAGEM DE PROGRAMAÇÃO I
#
#            unidade_responsavel situacao_turma  capacidade_aluno  \
# 0  INSTITUTO METROPOLE DIGITAL    CONSOLIDADA                60
# 1  INSTITUTO METROPOLE DIGITAL    CONSOLIDADA                60
# 2  INSTITUTO METROPOLE DIGITAL    CONSOLIDADA                40
# 3  INSTITUTO METROPOLE DIGITAL    CONSOLIDADA                40
# 4  INSTITUTO METROPOLE DIGITAL    CONSOLIDADA                30
#
#                  descricao_horario
# 0  24M12 (25/07/2016 - 17/12/2016)
# 1  35M34 (25/07/2016 - 17/12/2016)
# 2   3M56 (25/07/2016 - 17/12/2016)
# 3   5M56 (25/07/2016 - 17/12/2016)
# 4  35T34 (25/07/2016 - 17/12/2016)

# %%
from __future__ import print_function
from ipywidgets import interact, interactive, fixed, interact_manual

def evolucao(x):
    dados_prof = av_imd_nomesprof.loc[av_imd_nomesprof['nome_docente'] == x]
    return (dados_prof)

interact(evolucao, x=lista_prof,);
# Out:
# interactive(children=(Dropdown(description='x', options=('ADJA FERREIRA DE ANDRADE', 'ALLAN DE MEDEIROS MARTINS', 'ALUIZIO FERREIRA DA ROCHA NETO', 'ALYSON MATHEUS DE CARVALHO SOUZA', 'ANDRE LUIZ DA SILVA SOLINO', 'ANDRE MAURICIO CUNHA CAMPOS', 'ANNE MAGALY DE PAULA CANUTO', 'ANTONIO IGOR SILVA DE OLIVEIRA', 'ANTONIO WALLACE ANTUNES SOARES', 'ATHANASIOS TSOUANAS', 'AUGUSTO JOSE VENANCIO NETO', 'BRUNO SANTANA DA SILVA', 'CARLOS AUGUSTO PROLO', 'CESAR RENNO COSTA', 'CHARLES ANDRYE GALVAO MADEIRA', 'DANILO CURVELO DE SOUZA', 'DENNYS LEITE MAIA', 'DIOMADSON RODRIGUES BELFORT', 'EDGARD DE FARIA CORREA', 'EDUARDO NOGUEIRA CUNHA', 'EIJI ADACHI MEDEIROS BARBOSA', 'EVERTON RANIELLY DE SOUSA CAVALCANTE', 'GIBEON SOARES DE AQUINO JUNIOR', 'GUSTAVO GIRAO BARRETO DA SILVA', 'IRIS LINHARES PIMENTA', 'ISAAC FRANCO FERNANDES', 'ISABEL DILLMANN NUNES', 'ITAMIR DE MORAIS BARROCA FILHO', 'IVANOVITCH MEDEIROS DANTAS DA SILVA', 'JOAO CARLOS XAVIER JUNIOR', 'JOAO MARCOS DE ALMEIDA', 'JORGE ESTEFANO SANTANA DE SOUZA', 'JULIO CESAR PAULINO DE MELO', 'LORENA AZEVEDO DE SOUSA', 'LOURENA KARIN DE MEDEIROS ROCHA', 'LUCELIO DANTAS DE AQUINO', 'MARCIA JACYNTHA NUNES RODRIGUES LUCENA', 'MONICA MAGALHAES PEREIRA', 'NELSON ION DE OLIVEIRA', 'RAFAELA HORACINA SILVA ROCHA SOARES', 'SAMYR SILVA BEZERRA JACOME', 'SELAN RODRIGUES DOS SANTOS', 'SILVIA MARIA DINIZ MONTEIRO MAIA', 'SILVIO COSTA SAMPAIO', 'UMBERTO RIVIECCIO', 'UMBERTO SOUZA DA COSTA', 'VICENTE ANGELO DE SOUSA JUNIOR', 'WELLINGTON SILVA DE SOUZA', 'WILLIAM BRENNO DOS SANTOS OLIVEIRA'), value='ADJA FERREIRA DE ANDRADE'), Output()), _dom_classes=('widget-interact',))

# %%
% matplotlib inline
from ipywidgets import interactive
import matplotlib.pyplot as plt
import numpy as np
def evolucaoGrafico(x):
    dados_prof = av_imd_nomesprof.loc[av_imd_nomesprof['nome_docente'] == x]
    plt.plot(dados_prof['nome'], dados_prof['postura_profissional_media'])
    plt.show()
    
interactive_plot = interact(evolucaoGrafico, x=lista_prof,)
interactive_plot
# Out:
# interactive(children=(Dropdown(description='x', options=('ADJA FERREIRA DE ANDRADE', 'ALLAN DE MEDEIROS MARTINS', 'ALUIZIO FERREIRA DA ROCHA NETO', 'ALYSON MATHEUS DE CARVALHO SOUZA', 'ANDRE LUIZ DA SILVA SOLINO', 'ANDRE MAURICIO CUNHA CAMPOS', 'ANNE MAGALY DE PAULA CANUTO', 'ANTONIO IGOR SILVA DE OLIVEIRA', 'ANTONIO WALLACE ANTUNES SOARES', 'ATHANASIOS TSOUANAS', 'AUGUSTO JOSE VENANCIO NETO', 'BRUNO SANTANA DA SILVA', 'CARLOS AUGUSTO PROLO', 'CESAR RENNO COSTA', 'CHARLES ANDRYE GALVAO MADEIRA', 'DANILO CURVELO DE SOUZA', 'DENNYS LEITE MAIA', 'DIOMADSON RODRIGUES BELFORT', 'EDGARD DE FARIA CORREA', 'EDUARDO NOGUEIRA CUNHA', 'EIJI ADACHI MEDEIROS BARBOSA', 'EVERTON RANIELLY DE SOUSA CAVALCANTE', 'GIBEON SOARES DE AQUINO JUNIOR', 'GUSTAVO GIRAO BARRETO DA SILVA', 'IRIS LINHARES PIMENTA', 'ISAAC FRANCO FERNANDES', 'ISABEL DILLMANN NUNES', 'ITAMIR DE MORAIS BARROCA FILHO', 'IVANOVITCH MEDEIROS DANTAS DA SILVA', 'JOAO CARLOS XAVIER JUNIOR', 'JOAO MARCOS DE ALMEIDA', 'JORGE ESTEFANO SANTANA DE SOUZA', 'JULIO CESAR PAULINO DE MELO', 'LORENA AZEVEDO DE SOUSA', 'LOURENA KARIN DE MEDEIROS ROCHA', 'LUCELIO DANTAS DE AQUINO', 'MARCIA JACYNTHA NUNES RODRIGUES LUCENA', 'MONICA MAGALHAES PEREIRA', 'NELSON ION DE OLIVEIRA', 'RAFAELA HORACINA SILVA ROCHA SOARES', 'SAMYR SILVA BEZERRA JACOME', 'SELAN RODRIGUES DOS SANTOS', 'SILVIA MARIA DINIZ MONTEIRO MAIA', 'SILVIO COSTA SAMPAIO', 'UMBERTO RIVIECCIO', 'UMBERTO SOUZA DA COSTA', 'VICENTE ANGELO DE SOUSA JUNIOR', 'WELLINGTON SILVA DE SOUZA', 'WILLIAM BRENNO DOS SANTOS OLIVEIRA'), value='ADJA FERREIRA DE ANDRADE'), Output()), _dom_classes=('widget-interact',))
# <function __main__.evolucaoGrafico>

# %%
turmas2 = pd.read_csv('Dados Turma/turmas-2016.1.csv', sep=';')
turmas2.head()
# Out:
#    id_turma codigo_turma  id_docente_interno  id_docente_externo observacao  \
# 0  57562257           01                 NaN         109881493.0        NaN
# 1  57562261           02           5752206.0                 NaN        NaN
# 2  57562261           02                 NaN         109881524.0        NaN
# 3  57562265           03           5752206.0                 NaN        NaN
# 4  57562265           03                 NaN         110569107.0        NaN
#
#    id_componente_curricular nivel_ensino campus_turma local   ano     ...      \
# 0                     56847   LATO SENSU          NaN   NaN  2016     ...
# 1                     56847   LATO SENSU          NaN   NaN  2016     ...
# 2                     56847   LATO SENSU          NaN   NaN  2016     ...
# 3                     56847   LATO SENSU          NaN   NaN  2016     ...
# 4                     56847   LATO SENSU          NaN   NaN  2016     ...
#
#       tipo distancia        data_consolidacao agrupadora  id_turma_agrupadora  \
# 0  REGULAR         t  2016-05-30 13:42:46.443          f                  NaN
# 1  REGULAR         t  2016-05-25 10:05:57.996          f                  NaN
# 2  REGULAR         t  2016-05-25 10:05:57.996          f                  NaN
# 3  REGULAR         t  2016-06-13 08:59:37.463          f                  NaN
# 4  REGULAR         t  2016-06-13 08:59:37.463          f                  NaN
#
#    qtd_aulas_lancadas situacao_turma convenio modalidade_participantes  \
# 0                 0.0    CONSOLIDADA      NaN              A Distância
# 1                 0.0    CONSOLIDADA      NaN              A Distância
# 2                 0.0    CONSOLIDADA      NaN              A Distância
# 3                 0.0    CONSOLIDADA      NaN              A Distância
# 4                 0.0    CONSOLIDADA      NaN              A Distância
#
#   Unnamed: 25
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
#
# [5 rows x 26 columns]

# %%
turmas2.rename(columns={'id_componente_curricular': 'id_componente'}, inplace=True)
turmas2.id_componente = turmas.id_componente.astype(str)

# %%
disciplinas.head()
# Out:
#   id_componente  codigo nivel                              nome  \
# 0         18643  MUT508     T  COMPOSIÇÃO EM MÚSICA POPULAR III
# 1         18644  MUT516     T                      CO-REPETIÇÃO
# 2         18645  MUT520     T            CONTRABAIXO ACÚSTICO I
# 3         18646  MUT165     T              PIANO COMPLEMENTAR I
# 4         18647  MUT167     T            PIANO COMPLEMENTAR III
#
#   unidade_responsavel
# 0    ESCOLA DE MÚSICA
# 1    ESCOLA DE MÚSICA
# 2    ESCOLA DE MÚSICA
# 3    ESCOLA DE MÚSICA
# 4    ESCOLA DE MÚSICA

# %%
turmas2.head()
# Out:
#    id_turma codigo_turma  id_docente_interno  id_docente_externo observacao  \
# 0  57562257           01                 NaN         109881493.0        NaN
# 1  57562261           02           5752206.0                 NaN        NaN
# 2  57562261           02                 NaN         109881524.0        NaN
# 3  57562265           03           5752206.0                 NaN        NaN
# 4  57562265           03                 NaN         110569107.0        NaN
#
#   id_componente nivel_ensino campus_turma local   ano     ...         tipo  \
# 0         53901   LATO SENSU          NaN   NaN  2016     ...      REGULAR
# 1         18815   LATO SENSU          NaN   NaN  2016     ...      REGULAR
# 2         18778   LATO SENSU          NaN   NaN  2016     ...      REGULAR
# 3         18652   LATO SENSU          NaN   NaN  2016     ...      REGULAR
# 4         18652   LATO SENSU          NaN   NaN  2016     ...      REGULAR
#
#   distancia        data_consolidacao agrupadora  id_turma_agrupadora  \
# 0         t  2016-05-30 13:42:46.443          f                  NaN
# 1         t  2016-05-25 10:05:57.996          f                  NaN
# 2         t  2016-05-25 10:05:57.996          f                  NaN
# 3         t  2016-06-13 08:59:37.463          f                  NaN
# 4         t  2016-06-13 08:59:37.463          f                  NaN
#
#    qtd_aulas_lancadas situacao_turma convenio modalidade_participantes  \
# 0                 0.0    CONSOLIDADA      NaN              A Distância
# 1                 0.0    CONSOLIDADA      NaN              A Distância
# 2                 0.0    CONSOLIDADA      NaN              A Distância
# 3                 0.0    CONSOLIDADA      NaN              A Distância
# 4                 0.0    CONSOLIDADA      NaN              A Distância
#
#   Unnamed: 25
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
#
# [5 rows x 26 columns]

# %%
colunas = ["id_turma","id_docente_interno","codigo","nivel_ensino","nome","unidade_responsavel",
          "situacao_turma","capacidade_aluno","descricao_horario"]

merge_turmas_disciplinas2 = pd.merge(turmas2, disciplinas, on='id_componente')[colunas]
merge_turmas_disciplinas2.dropna(inplace=True)
merge_turmas_disciplinas2.head()
# Out:
#     id_turma  id_docente_interno  codigo nivel_ensino     nome  \
# 11  57573186             23400.0  MUT497      TÉCNICO  RECITAL
# 12  57573187             26652.0  MUT497      TÉCNICO  RECITAL
# 13  57573188             22886.0  MUT497      TÉCNICO  RECITAL
# 14  57573189             22886.0  MUT497      TÉCNICO  RECITAL
# 15  57573271           5751559.0  MUT497      TÉCNICO  RECITAL
#
#    unidade_responsavel situacao_turma  capacidade_aluno descricao_horario
# 11    ESCOLA DE MÚSICA    CONSOLIDADA               3.0             3T123
# 12    ESCOLA DE MÚSICA       EXCLUÍDA              50.0            4T1234
# 13    ESCOLA DE MÚSICA    CONSOLIDADA               3.0             4T123
# 14    ESCOLA DE MÚSICA    CONSOLIDADA               3.0             4T456
# 15    ESCOLA DE MÚSICA       EXCLUÍDA               3.0             3T456

# %%
# filtrando as turmas com código IMD
turmas_imd2 = merge_turmas_disciplinas2[merge_turmas_disciplinas2.codigo.str.contains("IMD")]

# utilizar apenas disciplinas com código "CONSOLIDADA"
turmas_imd2 = turmas_imd2[turmas_imd2.situacao_turma == 'CONSOLIDADA']

# Adaptar o nome da coluna id_docente_interno para id_servidor
turmas_imd2.rename(columns={'id_docente_interno': 'id_servidor'}, inplace=True)

turmas_imd2.capacidade_aluno = turmas_imd2.capacidade_aluno.astype(np.int64)

# Adaptar os tipos de dados em turmas_imd para o merge com o dataframe docentes
turmas_imd2.id_servidor = turmas_imd2.id_servidor.astype(np.int64)
turmas_imd2.head()
# Out:
#       id_turma  id_servidor   codigo nivel_ensino  \
# 3564  57575347      5756239  IMD0029    GRADUAÇÃO
# 3565  57575484        22907  IMD0029    GRADUAÇÃO
# 3566  57575486      2300648  IMD0029    GRADUAÇÃO
# 3567  57575486        22869  IMD0029    GRADUAÇÃO
# 3568  57575486        37281  IMD0029    GRADUAÇÃO
#
#                               nome          unidade_responsavel  \
# 3564  ESTRUTURA DE DADOS BÁSICAS I  INSTITUTO METROPOLE DIGITAL
# 3565  ESTRUTURA DE DADOS BÁSICAS I  INSTITUTO METROPOLE DIGITAL
# 3566  ESTRUTURA DE DADOS BÁSICAS I  INSTITUTO METROPOLE DIGITAL
# 3567  ESTRUTURA DE DADOS BÁSICAS I  INSTITUTO METROPOLE DIGITAL
# 3568  ESTRUTURA DE DADOS BÁSICAS I  INSTITUTO METROPOLE DIGITAL
#
#      situacao_turma  capacidade_aluno                 descricao_horario
# 3564    CONSOLIDADA                30  35M234 (05/05/2016 - 18/06/2016)
# 3565    CONSOLIDADA                 6   24M12 (01/02/2016 - 18/06/2016)
# 3566    CONSOLIDADA                 6   24M12 (01/02/2016 - 18/06/2016)
# 3567    CONSOLIDADA                 6   24M12 (01/02/2016 - 18/06/2016)
# 3568    CONSOLIDADA                 6   24M12 (01/02/2016 - 18/06/2016)

# %%
# merge os dataframes  turmas_imd e docentes utilizando como base a coluna id_servidor

colunas = ["id_turma", "codigo", "nivel_ensino", "nome_y",
          "nome_x","capacidade_aluno", "descricao_horario"]
turmas_imd_nomesprof2 = pd.merge(turmas_imd2, docentes, on='id_servidor')[colunas]
lista_prof2 = turmas_imd_nomesprof2.nome_y.unique()

# %%
lista_prof2.sort()
turmas_imd_nomesprof2.head()
# Out:
#    id_turma   codigo nivel_ensino                  nome_y  \
# 0  57575347  IMD0029    GRADUAÇÃO   DIEGO ANDRES LAPLAGNE
# 1  57575484  IMD0029    GRADUAÇÃO  GILMAR AMORIM DE SOUSA
# 2  57575486  IMD0030    GRADUAÇÃO  GILMAR AMORIM DE SOUSA
# 3  57575488  IMD0030    GRADUAÇÃO  GILMAR AMORIM DE SOUSA
# 4  57575486  IMD0029    GRADUAÇÃO       ENIO CAMPOS AMICO
#
#                          nome_x  capacidade_aluno  \
# 0  ESTRUTURA DE DADOS BÁSICAS I                30
# 1  ESTRUTURA DE DADOS BÁSICAS I                 6
# 2    LINGUAGEM DE PROGRAMAÇÃO I                 6
# 3    LINGUAGEM DE PROGRAMAÇÃO I                 6
# 4  ESTRUTURA DE DADOS BÁSICAS I                 6
#
#                   descricao_horario
# 0  35M234 (05/05/2016 - 18/06/2016)
# 1   24M12 (01/02/2016 - 18/06/2016)
# 2   24M12 (01/02/2016 - 18/06/2016)
# 3   24M12 (01/02/2016 - 18/06/2016)
# 4   24M12 (01/02/2016 - 18/06/2016)

# %%
#Essa celula pega a avaliação dos professores do imd
avaliacao = pd.read_csv("avaliacaodocencia.csv", sep=';')
av_imd = avaliacao[avaliacao['nome_docente'].isin(lista_prof2)]
av_imd.head()
# Out:
#       id_docente              nome_docente  id_turma   ano  periodo  \
# 4310       19582  JOSE VERISSIMO FERNANDES   1209382  2013        2
# 4311       19582  JOSE VERISSIMO FERNANDES   1210724  2013        2
# 4312       19582  JOSE VERISSIMO FERNANDES   1210734  2013        2
# 4313       19582  JOSE VERISSIMO FERNANDES   1211258  2013        2
# 4314       19582  JOSE VERISSIMO FERNANDES   1219949  2014        1
#
#       qtd_discentes  postura_profissional_media  postura_profissional_DP  \
# 4310             33                        9.08                     1.55
# 4311             20                        9.42                     1.46
# 4312             20                        9.75                     0.63
# 4313             50                        9.88                     0.55
# 4314             18                        9.91                     0.29
#
#       atuacao_profissional_media  atuacao_profissional_DP  \
# 4310                        8.24                     2.13
# 4311                        8.29                     1.86
# 4312                        8.96                     1.40
# 4313                        9.65                     0.92
# 4314                        7.99                     2.44
#
#       autoavaliacao_aluno_media  autoavaliacao_aluno_DP
# 4310                       8.67                    1.97
# 4311                       8.54                    2.32
# 4312                       8.88                    1.77
# 4313                       9.29                    1.69
# 4314                       8.60                    2.36

# %%
av_imd_nomesprof2 = pd.merge(av_imd, turmas_imd2, on='id_turma')
av_imd_nomesprof2.head()
# Out:
#    id_docente                      nome_docente  id_turma   ano  periodo  \
# 0       19582          JOSE VERISSIMO FERNANDES  57578146  2016        1
# 1       20854  MARIA TEREZA BARRETO DE OLIVEIRA  57575470  2016        1
# 2       21470  REGINA DE FATIMA DOS SANTOS BRAZ  57575439  2016        1
# 3       21990            DEUSIMAR FREIRE BRASIL  57575400  2016        1
# 4       22869                   SAMIR ASSI JOAO  57575471  2016        1
#
#    qtd_discentes  postura_profissional_media  postura_profissional_DP  \
# 0             22                        9.83                     0.38
# 1             14                        9.77                     0.53
# 2             51                        9.81                     0.69
# 3             11                        9.86                     0.36
# 4             45                        9.33                     1.65
#
#    atuacao_profissional_media  atuacao_profissional_DP  \
# 0                        8.97                     1.72
# 1                        9.63                     0.81
# 2                        8.54                     2.32
# 3                        9.55                     0.83
# 4                        8.63                     2.43
#
#    autoavaliacao_aluno_media  autoavaliacao_aluno_DP  id_servidor     codigo  \
# 0                       9.09                    1.60        19582    IMD0703
# 1                       9.32                    1.45        20854    IMD0034
# 2                       9.04                    1.97        21470  IMD0012.0
# 3                       9.39                    1.22        21990    IMD0017
# 4                       9.64                    0.94      5754345    IMD0034
#
#   nivel_ensino                                          nome  \
# 0    GRADUAÇÃO                            SEGURANÇA DE REDES
# 1    GRADUAÇÃO                 VETORES E GEOMETRIA ANALÍTICA
# 2    GRADUAÇÃO         INTRODUÇÃO ÀS TÉCNICAS DE PROGRAMAÇÃO
# 3    GRADUAÇÃO  PRÁTICAS DE LEITURA E ESCRITA EM PORTUGUÊS I
# 4    GRADUAÇÃO                 VETORES E GEOMETRIA ANALÍTICA
#
#            unidade_responsavel situacao_turma  capacidade_aluno  \
# 0  INSTITUTO METROPOLE DIGITAL    CONSOLIDADA                35
# 1  INSTITUTO METROPOLE DIGITAL    CONSOLIDADA                50
# 2  INSTITUTO METROPOLE DIGITAL    CONSOLIDADA                60
# 3  INSTITUTO METROPOLE DIGITAL    CONSOLIDADA                20
# 4  INSTITUTO METROPOLE DIGITAL    CONSOLIDADA                56
#
#   descricao_horario
# 0         4N34 5N12
# 1        4M123 5M34
# 2             3M234
# 3             46M23
# 4             35M12

# %%
from __future__ import print_function
from ipywidgets import interact, interactive, fixed, interact_manual

def evolucao(x):
    dados_prof = av_imd_nomesprof2.loc[av_imd_nomesprof2['nome_docente'] == x]
    return (dados_prof)

interact(evolucao, x=lista_prof2,);
# Out:
# interactive(children=(Dropdown(description='x', options=('ANA CRISTINA ARAUJO DE ANDRADE GALVAO', 'ANDRE FERRER PINTO MARTINS', 'ANDRE LUIS PINTO SOARES', 'ANNE CHRISTINE DAMASIO', 'AUZELIVIA PASTORA REGO MEDEIROS FALCAO', 'CARLA ALMEIDA VIVACQUA', 'CARLOS ALBERTO ALMEIDA DE ARAUJO', 'CAROLINE ADDISON CARVALHO XAVIER DE MEDEIROS', 'CLEONICE ANDREA ALVES CAVALCANTE', 'DANIELLE SOARES BEZERRA', 'DEUSIMAR FREIRE BRASIL', 'DIEGO ANDRES LAPLAGNE', 'ENIO CAMPOS AMICO', 'EUZEBIO GUIMARAES BARBOSA', 'EZEQUIAS OLIVEIRA LIRA', 'FABIANA BARBOSA GONCALVES', 'FABIANA CRISTINA MENDONCA DE ARAUJO', 'FABIANA LIMA BEZERRA', 'FABRICIO PITOMBO LEITE', 'FERNANDA DA FONSECA FREITAS', 'FLAVIO EDUARDO FALCAO LEMOS', 'GERLANE COELHO BERNARDO GUERRA', 'GILMAR AMORIM DE SOUSA', 'JACILEIDE GUIMARAES', 'JORGE EDUARDO LINS OLIVEIRA', 'JOSE BRUNO DE ALMEIDA', 'JOSE VERISSIMO FERNANDES', 'KATYA ANAYA JACINTO', 'KELLY SAMARA DE LIRA MOTA', 'LINDEMBERG DE JESUS NOGUEIRA DUARTE', 'LUCIANNA PEREIRA DA MOTTA PIRES CORREIA', 'MAGNA ANGELICA DOS SANTOS BEZERRA SOUSA', 'MAGNOLIA FERNANDES FLORENCIO DE ARAUJO', 'MARCELO HENRIQUE NEVES PEREIRA', 'MARCIA MARIA DE OLIVEIRA BEZERRA', 'MARCIO ROMEU RIBAS DE OLIVEIRA', 'MARCIO VIEIRA DA SILVA', 'MARCOS ADLLER DE ALMEIDA NASCIMENTO', 'MARGARETH DE VASCONCELOS MONTEIRO', 'MARIA INES SUCUPIRA STAMATTO', 'MARIA TEREZA BARRETO DE OLIVEIRA', 'MARILENE BIZERRA DA COSTA', 'MAURICIO GALVAO PEREIRA', 'MOISES DOMINGOS SOBRINHO', 'ORIONE DANTAS DE MEDEIROS', 'PAULA REJANE FERNANDES', 'PAULO ROBERTO DE ALBUQUERQUE', 'PIO MARINHEIRO DE SOUZA NETO', 'REGINA DE FATIMA DOS SANTOS BRAZ', 'RENATA VEIGA ANDERSEN CAVALCANTI', 'RENATO DE ALBUQUERQUE MEDEIROS', 'REYNALDO MARTINS E QUININO', 'RICARDO WAGNER DE ARAUJO', 'ROSANGELA DOS SANTOS ALVES PEQUENO', 'RUTACIO DE OLIVEIRA COSTA', 'SAMIR ASSI JOAO', 'SANDRA MICHELLE BESSA DE ANDRADE FERNANDES', 'SERGIO JOSE GONCALVES E SILVA', 'SERGIO RAMIRO RIVERO GUARDIA', 'SUELENE SUASSUNA SILVESTRE DE ALENCAR', 'SUZIANNE RUTH HOSANAH LIMA', 'TIRZAH BRAZ PETTA LAJUS', 'VANESSA TEIXEIRA DE LIMA OLIVEIRA', 'VIRGINIA MARIA CAVALARI HENRIQUES', 'WILACI EUTROPIO FERNANDES JUNIOR'), value='ANA CRISTINA ARAUJO DE ANDRADE GALVAO'), Output()), _dom_classes=('widget-interact',))

# %%
% matplotlib inline
from ipywidgets import interactive
import matplotlib.pyplot as plt
import numpy as np
def evolucaoGrafico(x):
    dados_prof2 = av_imd_nomesprof2.loc[av_imd_nomesprof2['nome_docente'] == x]
    plt.plot(dados_prof2['nome'], dados_prof2['postura_profissional_media'])
    plt.xticks(rotation=90)
    plt.show()
    
interactive_plot = interact(evolucaoGrafico, x=lista_prof2,)

interactive_plot
# Out:
# interactive(children=(Dropdown(description='x', options=('ANA CRISTINA ARAUJO DE ANDRADE GALVAO', 'ANDRE FERRER PINTO MARTINS', 'ANDRE LUIS PINTO SOARES', 'ANNE CHRISTINE DAMASIO', 'AUZELIVIA PASTORA REGO MEDEIROS FALCAO', 'CARLA ALMEIDA VIVACQUA', 'CARLOS ALBERTO ALMEIDA DE ARAUJO', 'CAROLINE ADDISON CARVALHO XAVIER DE MEDEIROS', 'CLEONICE ANDREA ALVES CAVALCANTE', 'DANIELLE SOARES BEZERRA', 'DEUSIMAR FREIRE BRASIL', 'DIEGO ANDRES LAPLAGNE', 'ENIO CAMPOS AMICO', 'EUZEBIO GUIMARAES BARBOSA', 'EZEQUIAS OLIVEIRA LIRA', 'FABIANA BARBOSA GONCALVES', 'FABIANA CRISTINA MENDONCA DE ARAUJO', 'FABIANA LIMA BEZERRA', 'FABRICIO PITOMBO LEITE', 'FERNANDA DA FONSECA FREITAS', 'FLAVIO EDUARDO FALCAO LEMOS', 'GERLANE COELHO BERNARDO GUERRA', 'GILMAR AMORIM DE SOUSA', 'JACILEIDE GUIMARAES', 'JORGE EDUARDO LINS OLIVEIRA', 'JOSE BRUNO DE ALMEIDA', 'JOSE VERISSIMO FERNANDES', 'KATYA ANAYA JACINTO', 'KELLY SAMARA DE LIRA MOTA', 'LINDEMBERG DE JESUS NOGUEIRA DUARTE', 'LUCIANNA PEREIRA DA MOTTA PIRES CORREIA', 'MAGNA ANGELICA DOS SANTOS BEZERRA SOUSA', 'MAGNOLIA FERNANDES FLORENCIO DE ARAUJO', 'MARCELO HENRIQUE NEVES PEREIRA', 'MARCIA MARIA DE OLIVEIRA BEZERRA', 'MARCIO ROMEU RIBAS DE OLIVEIRA', 'MARCIO VIEIRA DA SILVA', 'MARCOS ADLLER DE ALMEIDA NASCIMENTO', 'MARGARETH DE VASCONCELOS MONTEIRO', 'MARIA INES SUCUPIRA STAMATTO', 'MARIA TEREZA BARRETO DE OLIVEIRA', 'MARILENE BIZERRA DA COSTA', 'MAURICIO GALVAO PEREIRA', 'MOISES DOMINGOS SOBRINHO', 'ORIONE DANTAS DE MEDEIROS', 'PAULA REJANE FERNANDES', 'PAULO ROBERTO DE ALBUQUERQUE', 'PIO MARINHEIRO DE SOUZA NETO', 'REGINA DE FATIMA DOS SANTOS BRAZ', 'RENATA VEIGA ANDERSEN CAVALCANTI', 'RENATO DE ALBUQUERQUE MEDEIROS', 'REYNALDO MARTINS E QUININO', 'RICARDO WAGNER DE ARAUJO', 'ROSANGELA DOS SANTOS ALVES PEQUENO', 'RUTACIO DE OLIVEIRA COSTA', 'SAMIR ASSI JOAO', 'SANDRA MICHELLE BESSA DE ANDRADE FERNANDES', 'SERGIO JOSE GONCALVES E SILVA', 'SERGIO RAMIRO RIVERO GUARDIA', 'SUELENE SUASSUNA SILVESTRE DE ALENCAR', 'SUZIANNE RUTH HOSANAH LIMA', 'TIRZAH BRAZ PETTA LAJUS', 'VANESSA TEIXEIRA DE LIMA OLIVEIRA', 'VIRGINIA MARIA CAVALARI HENRIQUES', 'WILACI EUTROPIO FERNANDES JUNIOR'), value='ANA CRISTINA ARAUJO DE ANDRADE GALVAO'), Output()), _dom_classes=('widget-interact',))
# <function __main__.evolucaoGrafico>
